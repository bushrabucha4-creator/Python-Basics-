# %% [markdown]
# Basic Python Programs

# %%
age=20;
if age>=18:
    print("adult")
# Out:
# adult

# %% [markdown]
# To check given number is Even or Odd

# %%
number=7;
if number % 2 == 0:
 print("Even")
else:
 print("odd")
# Out:
# odd

# %% [markdown]
# print marklist usimg if -elif conditions

# %%
mark=78;
if mark>=90:
    grade="A+"
elif mark>=80:
    grade="A"
elif mark>=70:
    grade="B"
elif mark>=60:
    grade="c"

# %% [markdown]
# for loop

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
age=38;
if  1<=age<18:
   catagory="Child"
elif 18<=age<=30:
   catagory="adult"
else: catagory="senior citizen"
print(catagory)
# Out:
# senior citizen

# %%
for i in range(1,6):#range(starting value,ending value)
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# enumerate() is using to print index and value .

# %%
students=["Anu","Rahul","Meera"]
for index,name in enumerate(students):print(index,name)
# Out:
# 0 Anu
# 1 Rahul
# 2 Meera

# %%
students={"name":"Anu","mark":92}
print(students)
print(students["name"])#to print student name
print(students["mark"])#To print mark
# Out:
# {'name': 'Anu', 'mark': 92}
# Anu
# 92

# %%
student={"name":"Rahul","age":21 ,"mark":88}
print(student)
# Out:
# {'name': 'Rahul', 'age': 21, 'mark': 88}

# %%
student
# Out:
# {'name': 'Rahul', 'age': 21, 'mark': 91}

# %%
student["city"]="kochi"#add new key -value in student dict

# %%
student["mark"]=91 #to change mark

# %%
student
# Out:
# {'name': 'Rahul', 'age': 21, 'mark': 91, 'city': 'kochi'}

# %%
for value in student.values():
    print(value)
# Out:
# Rahul
# 21
# 91
# kochi

# %%
age=17
status="Adult" if age>=18 else "Minor"
print(status)
# Out:
# Minor

# %% [markdown]
# While loop

# %%
i=1
while i<=5:
    print(i)
    if i==3:
        break
    i+=1
else:
    print("loop completed")
# Out:
# 1
# 2
# 3
